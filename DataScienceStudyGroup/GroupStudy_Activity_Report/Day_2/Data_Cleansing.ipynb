% %% [markdown]
% # [ Cleansing(Processing) ]
%
% ## 분석, 선형회귀, 머신러닝을 하기 위해 = > 데이터를 가공해서 바로 떠먹을 수 있는 형태로 전달해주는 것

% %% [markdown]
% # File : cleansing.docx
% ### 문제 같이 고민해보기

% %% [markdown]
% # [ Main Issues ]

% %% [markdown]
% ### 1. 범주형 값 ? => 1. 독립된 노드로 만들기 2. 이진법 형태로 구분
%
% ### 2. 현실적으로 Null 값 ? => 1. Median, 최빈값 대체 2. 노드독립
%
% ### 3. Normalize ? => 모두가 업데이트될 권리가 있드아! => Z-score OR log & z-score (통과는 어떻게 보실지?)
%
% ### 4. Outliers? 그래프보고, 아웃라이어 삭제 / 데이터 손실이 크지 않다면 2$\sigma$ 이외의 것들 삭제

% %% [markdown]
% ![Screen%20Shot%202019-07-11%20at%208.00.50%20PM.png](attachment:Screen%20Shot%202019-07-11%20at%208.00.50%20PM.png)
