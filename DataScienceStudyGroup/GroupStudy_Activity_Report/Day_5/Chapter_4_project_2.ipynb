# %% [markdown]
# # [Chapter_4]. project_2

# %% [markdown]
# ### Evaluate the robustness of Borda's method by applying k random swaps to each of m distinct copies of the permutation p = {1,2, ... n}. What is the threshold where Borda's method fails to reconstruct p, as a function of n,k and m ?

# %%
# 보르다 방법론이 실패할 때 : n개의 랭킹이 uniquely 하게 모든 조합으로 셔플되었을 때.

# 만약 4개의 대상이 있다고 할때 사람들은, 1,2,3,4의 등수를 먹이게 되는데.

# 만약 n은 평가받을 대상의 수
# m 은 서로 다른 랭킹 조합의 수
# k번의 랜덤 스와핑

# n개의 평가 대상이 있을 때, m이 k = 최대 n-1 번의 스와핑을 통해, n!개의 서로다른 조합이 되어버렸을 때부터
# 그것을 리컨스트럭트 하는 것이 의미가 없다.

# Borda's method fails when all 
# the possible n! of opitions are in m (uniquely identifiable) conbination appears. 
# ,when k = n -1 번. (no winner at all.)

# %% [markdown]
# ![Screen%20Shot%202019-07-25%20at%205.52.35%20PM.png](attachment:Screen%20Shot%202019-07-25%20at%205.52.35%20PM.png)
